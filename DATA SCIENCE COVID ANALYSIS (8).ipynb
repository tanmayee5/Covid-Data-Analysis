# %% [markdown]
# # Covid-19

# %% [markdown]
# ### About COVID-19

# %% [markdown]
# The coronavirus (COVID-19) pandemic has spread across 219 countries infecting 11.6 crore people and killing 2,593,182 so far. In India, as many as 2,593,182 COVID-19 cases have been reported so far(March 2021). Of these, 10,854,128 have recovered and 1,57,656 have died.
#
# On March 24,2020 Prime Minister Narendra Modi annouced that the country would go under 21-day lackdown to combat the spread of the virus.
# Then after it was extended till 31 May,2020.From June,2020 lockdown was only confined to only the containment zones.
# The outbreak of COVID-19 developed into a major international crisis, and it started to influence important aspects of daily life.

# %% [markdown]
# ## covid-19 Cases in INDIA

# %%
data = pd.read_csv('C:/Users/User/Documents/SEM -4/Data science/covidcases-state wise.csv')
print("Total covid cases in INDIA state wise ")
data
# Out:
# Total covid cases in INDIA state wise
#        #                                  State/UT  Confirmed Cases  \
# 0    NaN                                       NaN              NaN
# 1    1.0               Andaman and Nicobar Islands           5022.0
# 2    2.0                            Andhra Pradesh         890215.0
# 3    3.0                         Arunachal Pradesh          16838.0
# 4    4.0                                     Assam         217593.0
# 5    5.0                                     Bihar         262628.0
# 6    6.0                                Chandigarh          21962.0
# 7    7.0                              Chhattisgarh         313299.0
# 8    8.0  Dadra and Nagar Haveli and Daman and Diu           3408.0
# 9    9.0                                     Delhi         639921.0
# 10  10.0                                       Goa          55143.0
# 11  11.0                                   Gujarat         271245.0
# ...

# %%
data.sort_values(by=['Confirmed Cases'],ascending=False).head(38)
# Out:
#        #                                  State/UT  Confirmed Cases  \
# 21  21.0                               Maharashtra        2179185.0
# 17  17.0                                    Kerala        1067044.0
# 16  16.0                                 Karnataka         952565.0
# 2    2.0                            Andhra Pradesh         890215.0
# 31  31.0                                Tamil Nadu         852967.0
# 9    9.0                                     Delhi         639921.0
# 34  34.0                             Uttar Pradesh         603788.0
# 36  36.0                               West Bengal         575712.0
# 26  26.0                                    Odisha         337448.0
# 29  29.0                                 Rajasthan         320772.0
# 7    7.0                              Chhattisgarh         313299.0
# 32  32.0                                 Telangana         299406.0
# 12  12.0                                   Haryana         271365.0
# ...

# %% [markdown]
# # Vaccination

# %%
India’s COVID vaccination drive was scheduled to start on
January 16 2021 with priority given to an estimated three crore healthcare workers and the frontline workers,
followed by voluntary vaccination of those above 50 years of age and the under-50 population groups with co-morbidities.

Covishield and Covaxin are the two vaccines approved by Indian govt.

# %%
1,90,40,175 vaccine doses have been given so far (6 march 2021). These include 68,96,529 healthcare workers
who have taken the first dose and 32,94,612 healthcare workerswho have taken the second dose;
62,94,755 frontline workers who got their first, and 1,23,191 frontline workers whoreceived the second shot;
21,17,862 beneficiaries more than 60-years-old and 3,13,226 beneficiaries aged 45 and above with specific co-morbidities.

# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# ## How many days will take for the Covid-19 vaccine to reach all the people in India?

# %%
The current population of India in 2021 is 1,393,409,038, a 0.97% increase from 2020

# %% [markdown]
# ## vaccinations in INDIA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df_india = pd.read_csv('C:/Users/User/Documents/SEM -4/Data science/CumulativeCoverageReport4thMarch2021.csv')
print("Vaccinations in India State wise")
df_india
# Out:
# Vaccinations in India State wise
#     s.No.              State/UT   1st Dose  2nd Dose Total Doses
# 0       1         A & N Islands      6,912     2,589       9,501
# 1       2        Andhra Pradesh   5,94,085  1,54,853    7,48,938
# 2       3     Arunachal Pradesh     32,733     8,097      40,830
# 3       4                 Assam   2,79,061    37,045    3,16,106
# 4       5                 Bihar   6,01,638  1,40,711    7,42,349
# 5       6            Chandigarh     27,336     2,505      29,841
# 6       7          Chhattisgarh   4,46,330    88,875    5,35,205
# 7       8  Dadra & Nagar Haveli      5,892       718       6,610
# 8       9           Daman & Diu      3,735       622       4,357
# 9      10                 Delhi   4,46,950    52,820    4,99,770
# 10     11                   Goa     30,473     5,009      35,482
# 11     12               Gujarat  11,56,897  2,64,864   14,21,761
# 12     13               Haryana   2,51,481    81,934    3,33,415
# ...

# %% [markdown]
# ## vaccinations in UNITED STATES

# %%
df_us = pd.read_csv('C:/Users/User/Documents/SEM -4/Data science/rows.csv_accessType=DOWNLOAD')
print("Vaccinations in US")
df_us.head(10)
# Out:
# Vaccinations in US
#     Jurisdiction Week of Allocations  1st Dose Allocations  \
# 0    Connecticut          03/08/2021                 35800
# 1          Maine          03/08/2021                 13700
# 2  Massachusetts          03/08/2021                 69000
# 3  New Hampshire          03/08/2021                 13700
# 4   Rhode Island          03/08/2021                 10800
# 5        Vermont          03/08/2021                  6500
# 6     New Jersey          03/08/2021                 87400
# 7       New York          03/08/2021                111300
# 8  New York City          03/08/2021                 84500
# 9    Puerto Rico          03/08/2021                 34200
#
#    2nd Dose Allocations
# 0                 35800
# 1                 13700
# 2                 69000
# 3                 13700
# 4                 10800
# 5                  6500
# 6                 87400
# 7                111300
# 8                 84500
# 9                 34200

# %%
data = pd.read_csv('C:/Users/User/Documents/SEM -4/Data science/Total-D.csv')
print("TOTAL DOSES")
data
# Out:
# TOTAL DOSES
#     Total Doses
# 0          9501
# 1        748938
# 2         40830
# 3        316106
# 4        742349
# 5         29841
# 6        535205
# 7          6610
# 8          4357
# 9        499770
# 10        35482
# 11      1421761
# 12       333415
# 13       149904
# 14       299418
# 15       361482
# 16       879036
# 17       810847
# 18        12884
# 19         3216
# 20       998891
# 21      1471450
# 22        66423
# 23        37921
# 24        40058
# 25        41140
# 26       754651
# 27        16562
# 28       235698
# 29      1609343
# 30        24030
# 31       669417
# 32       472010
# 33       125814
# 34      1592712
# 35       206358
# 36      1376553
# 37      1025520

# %%
data['Total Doses'].sum()
# Out:
# 18005503

# %% [markdown]
# ## population in INDIA state wise

# %%
df1 = pd.read_csv('C:/Users/User/Documents/SEM -4/Data science/population-statewis_utf-8_file.csv',encoding='latin1')
print(" population in INDIA state wise")
df1
# Out:
#  population in INDIA state wise
#                     State or union territory    Population
# 0                              Uttar Pradesh  19,98,12,341
# 1                                Maharashtra  11,23,74,333
# 2                                      Bihar  10,40,99,452
# 3                                West Bengal   9,12,76,115
# 4                             Madhya Pradesh   7,26,26,809
# 5                                 Tamil Nadu   7,21,47,030
# 6                                  Rajasthan   6,85,48,437
# 7                                  Karnataka   6,10,95,297
# 8                                    Gujarat   6,04,39,692
# 9                             Andhra Pradesh   4,95,77,103
# 10                                    Odisha   4,19,74,219
# 11                                 Telangana   3,50,03,674
# 12                                    Kerala   3,34,06,061
# 13                                 Jharkhand   3,29,88,134
# ...

# %% [markdown]
# ## DOSE 1 vaccination DAY WISE

# %%
import pandas as pd
import numpy as np
df2 = pd.read_csv("C:/Users/User/Documents/SEM -4/Data science/datascienceproject/vaccination-day-wise-updated.csv")
print("DOSE 1 vaccination DAY WISE")
df2
# Out:
# DOSE 1 vaccination DAY WISE
#           Date  No of people vaccinated
# 0   16-01-2021                 191181.0
# 1   17-01-2021                  33120.0
# 2   18-01-2021                 229748.0
# 3   19-01-2021                 220786.0
# 4   20-01-2021                 131649.0
# ..         ...                      ...
# 84  10-04-2021                3122109.0
# 85  11-04-2021                2701439.0
# 86  12-04-2021                3455639.0
# 87  13-04-2021                2258875.0
# 88         NaN                      NaN
#
# [89 rows x 2 columns]

# %% [markdown]
# ### AVERAGE OF DOSE 1

# %%
dose1avg=df2['No of people vaccinated'].mean()
print("AVERAGE of vaccinations:",dose1avg)
# Out:
# AVERAGE of vaccinations: 1105911.8068181819

# %% [markdown]
# ## DOSE 2 vaccination DAY WISE

# %%
df3 = pd.read_csv("C:/Users/User/Documents/SEM -4/Data science/datascienceproject/vaccination-dose-2-updated.csv")
print("DOSE 2 vaccination DAY WISE")
df3
# Out:
# DOSE 2 vaccination DAY WISE
#           Date  No of people vaccinated(second dose)
# 0   15-02-2021                                 90450
# 1   16-02-2021                                118221
# 2   17-02-2021                                125777
# 3   18-02-2021                                122816
# 4   19-02-2021                                292010
# 5   20-02-2021                                116998
# 6   21-02-2021                                 86702
# 7   22-02-2021                                154900
# 8   23-02-2021                                206093
# 9   24-02-2021                                160119
# 10  25-01-2021                                379105
# 11  26-02-2021                                343224
# 12  27-02-2021                                249795
# 13  28-02-2021                                  2313
# 14  01-03-2021                                141608
# 15  02-03-2021                                116179
# ...

# %% [markdown]
# ### AVERAGE OF DOSE 2

# %%
dose2avg=df3['No of people vaccinated(second dose)'].mean()
print("AVGERAGE OF DOSE 2 VACIINATIONS:",dose2avg)
# Out:
# AVGERAGE OF DOSE 2 VACIINATIONS: 237827.5172413793

# %%
population = 1393409038

# %%
answer = population/dose1avg
answer
# Out:
# 1259.9639767017013

# %%
n=answer/365
n
# Out:
# 3.4519561005526063

# %% [markdown]
# ### Approximate time to dose to complete dose 1 for whole INDIA : 3.4 years

# %%
print(" years : ",n)
# Out:
#  years :  3.4519561005526063

# %%
ans2 = population/dose2avg
ans2
# Out:
# 5858.90587499083

# %%
ans= ans2/365
ans
# Out:
# 16.051796917783097

# %% [markdown]
# ### Approximate time to dose to complete dose 2 for whole INDIA : 16 years

# %%
print(" years : ",ans)
# Out:
#  years :  16.051796917783097

# %% [markdown]
# ### Avg no of vaccinations to be done per day to vaccinate entire indian population in 5 years
# #india population as of 18th March 2021(9:19 am)/(years)

# %%
a=1389792771/1825
a
# Out:
# 761530.2854794521

# %%
print("for completing 2 doses in 5 years avg of both dose 1 and dose 2 simulatinously is :",a*2)
# Out:
# for completing 2 doses in 5 years avg of both dose 1 and dose 2 simulatinously is : 1523060.5709589042

# %% [markdown]
# ### Avg no of vaccinations to be done per day to vaccinate entire indian population in 10 years

# %%
b=1389792771/3650
b
# Out:
# 380765.14273972606

# %%
print("for completing 2 doses in 10 years avg of both dose 1 and dose 2 simulatinously is :",b*2)
# Out:
# for completing 2 doses in 10 years avg of both dose 1 and dose 2 simulatinously is : 761530.2854794521

# %% [markdown]
# ### Avg no of vaccinations to be done per day to vaccinate entire indian population in 15 years

# %%
c=1389792771/5475
c
# Out:
# 253843.42849315068

# %%
print("for completing 2 doses in 15 years avg of both dose 1 and dose 2 simulatinously is :",c*2)
# Out:
# for completing 2 doses in 15 years avg of both dose 1 and dose 2 simulatinously is : 507686.85698630137
